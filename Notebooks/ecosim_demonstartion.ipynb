# %% [markdown]
# SIMULATION

# %%
import os
os.getcwd()
os.chdir("c:/Users/Surface/Documents/2024_25_4/ScientificPython/ecosim") # path/to/ecosim
os.getcwd()

import matplotlib
matplotlib.use('Agg')  # non-interactive backend, safe for file output

import main
main.simulation(10, 3)
# Out:
# --- Step 0 ---
# Carrot(6,9,E=100)
# Carrot(5,1,E=100)
# Carrot(1,6,E=100)
# Carrot(9,9,E=100)
# Rabbit(1,9,E=99)
# Rabbit(6,8,E=99)
# Rabbit(9,7,E=99)
# Rabbit(3,6,E=99)
# Rabbit(7,8,E=99)
# Rabbit(6,5,E=104)
# Rabbit(4,9,E=99)
# Rabbit(8,3,E=99)
# Rabbit(8,5,E=99)
# Rabbit(7,2,E=104)
# Rabbit(5,6,E=99)
# Rabbit(8,2,E=99)
# Rabbit(9,9,E=99)
# Rabbit(2,2,E=104)
# Rabbit(7,0,E=99)
# Fox(0,1,E=99)
# Fox(8,2,E=99)
# Fox(1,2,E=99)
# Fox(3,9,E=99)
# Fox(7,0,E=99)
# Fox(1,6,E=99)
# Fox(7,3,E=104)
#
# --- Step 1 ---
# Carrot(6,9,E=100)
# Carrot(5,1,E=100)
# Carrot(1,6,E=100)
# Carrot(9,9,E=100) X
# Rabbit(3,7,E=98)
# Rabbit(7,8,E=98)
# Rabbit(9,8,E=98)
# Rabbit(3,8,E=98)
# Rabbit(8,8,E=98)
# Rabbit(8,4,E=103)
# Rabbit(3,9,E=98) X
# Rabbit(7,2,E=98) X
# Rabbit(8,4,E=98)
# Rabbit(7,0,E=103) X
# Rabbit(4,5,E=98)
# Rabbit(7,2,E=98) X
# Rabbit(9,9,E=118)
# Rabbit(2,1,E=103)
# Rabbit(9,2,E=98)
# Fox(0,0,E=98)
# Fox(9,2,E=98)
# Fox(1,2,E=98)
# Fox(2,9,E=118)
# Fox(6,1,E=118)
# Fox(2,7,E=98)
# ...

# %%
import importlib
import visualizer.plot
importlib.reload(visualizer.plot)
from visualizer.plot import create_animation

os.chdir("c:/Users/Surface/Documents/2024_25_4/ScientificPython/ecosim") # path/to/ecosim
create_animation(frame_folder="frames", output_path="statistics_plots/animation.gif", frame_range=(0, 21))
# Out:
# ✅ Animation saved to statistics_plots/animation.gif

# %%
from visualizer.plot import compose_frames_side_by_side
compose_frames_side_by_side([1, 2])
# Out:
# ✅ Composed image saved to statistics_plots/frames_side_by_side.png

# %% [markdown]
# STATISZTIKA - HEATMAP

# %%
import importlib
import statistic_tools.heatmap
importlib.reload(statistic_tools.heatmap)

from statistic_tools.heatmap import display_heatmap
display_heatmap("Fox")

# %% [markdown]
# STATISZTIKA - POPULATION CHART

# %%
import importlib
import statistic_tools.population
importlib.reload(statistic_tools.population)

from statistic_tools.population import display_population_chart
display_population_chart()
