# %% [markdown]
# SIMULATION

# %%
import os
os.getcwd()
os.chdir("c:/Users/Surface/Documents/2024_25_4/ScientificPython/ecosim") # path/to/ecosim
os.getcwd()

import matplotlib
matplotlib.use('Agg')  # non-interactive backend, safe for file output

import main
main.main()
# Out:
# --- Step 0 ---
# Carrot(12,2,E=100)
# Carrot(12,1,E=100)
# Carrot(10,0,E=100)
# Carrot(18,9,E=100)
# Rabbit(6,18,E=99)
# Rabbit(19,17,E=99)
# Rabbit(3,0,E=99)
# Rabbit(5,16,E=99)
# Rabbit(13,18,E=99)
# Rabbit(12,16,E=99)
# Rabbit(8,16,E=99)
# Rabbit(11,12,E=99)
# Rabbit(13,17,E=99) X
# Rabbit(6,0,E=99)
# Rabbit(4,1,E=99)
# Rabbit(12,3,E=99)
# Rabbit(17,10,E=99)
# Rabbit(12,3,E=99)
# Rabbit(2,18,E=99)
# Fox(13,2,E=99)
# Fox(1,12,E=99)
# Fox(14,16,E=119)
# Fox(6,13,E=99)
# Fox(18,8,E=99)
# Fox(2,14,E=99)
# Fox(4,15,E=99)
#
# --- Step 1 ---
# Carrot(12,2,E=100)
# Carrot(12,1,E=100)
# Carrot(10,0,E=100)
# Carrot(18,9,E=100) X
# Rabbit(5,18,E=98)
# Rabbit(19,17,E=98)
# Rabbit(3,1,E=98)
# Rabbit(3,14,E=98)
# Rabbit(15,18,E=98)
# Rabbit(13,15,E=98)
# Rabbit(7,17,E=98)
# Rabbit(11,13,E=98)
# Rabbit(13,17,E=99) X
# Rabbit(5,0,E=98)
# Rabbit(3,2,E=98)
# Rabbit(14,2,E=98)
# Rabbit(19,8,E=118)
# Rabbit(12,2,E=98)
# Rabbit(2,17,E=98)
# Fox(14,2,E=98)
# Fox(1,11,E=98)
# Fox(14,15,E=118)
# Fox(7,12,E=98)
# Fox(19,9,E=98)
# Fox(1,13,E=98)
# Fox(5,15,E=98)
# Carrot(11,1,E=100)
# Carrot(10,1,E=100)
#
# --- Step 2 ---
# Carrot(12,2,E=100)
# Carrot(12,1,E=100)
# Carrot(10,0,E=100)
# Carrot(18,9,E=100) X
# Rabbit(6,17,E=97)
# Rabbit(19,17,E=97)
# Rabbit(3,2,E=97)
# Rabbit(3,15,E=97)
# Rabbit(15,19,E=97)
# Rabbit(15,15,E=97)
# Rabbit(8,16,E=97)
# Rabbit(11,14,E=97)
# Rabbit(13,17,E=99) X
# Rabbit(6,1,E=97)
# Rabbit(2,3,E=97)
# Rabbit(13,3,E=97)
# Rabbit(18,10,E=117)
# Rabbit(14,1,E=97)
# Rabbit(3,17,E=97)
# Fox(14,3,E=97)
# Fox(0,10,E=97)
# Fox(13,16,E=117)
# Fox(7,13,E=97)
# Fox(19,9,E=97)
# Fox(1,13,E=97)
# Fox(4,14,E=97)
# Carrot(11,1,E=100)
# Carrot(10,1,E=100)
#
# --- Step 3 ---
# Carrot(12,2,E=100)
# Carrot(12,1,E=100)
# Carrot(10,0,E=100)
# Carrot(18,9,E=100) X
# Rabbit(5,17,E=96)
# Rabbit(19,16,E=96)
# Rabbit(3,2,E=96)
# Rabbit(5,13,E=96)
# Rabbit(15,19,E=96)
# Rabbit(13,16,E=96) X
# Rabbit(8,17,E=96)
# Rabbit(10,13,E=96)
# Rabbit(13,17,E=99) X
# Rabbit(7,2,E=96)
# Rabbit(1,4,E=96)
# Rabbit(15,2,E=96)
# Rabbit(19,8,E=116)
# Rabbit(13,1,E=96)
# Rabbit(3,17,E=96)
# Fox(13,4,E=96)
# Fox(1,10,E=96)
# Fox(14,16,E=119)
# Fox(8,13,E=96)
# Fox(18,8,E=96)
# Fox(1,12,E=96)
# Fox(5,14,E=96)
# Carrot(11,1,E=100)
# Carrot(10,1,E=100)
# 💀 Decomposed: Carrot(18,9,E=100)
#
# --- Step 4 ---
# Carrot(12,2,E=100)
# Carrot(12,1,E=100)
# Carrot(10,0,E=100)
# Rabbit(6,16,E=95)
# Rabbit(19,17,E=95)
# Rabbit(4,1,E=95)
# Rabbit(6,15,E=95)
# Rabbit(15,19,E=95)
# Rabbit(13,16,E=96) X
# Rabbit(9,17,E=95)
# Rabbit(10,14,E=95)
# Rabbit(13,17,E=99) X
# Rabbit(7,2,E=95)
# Rabbit(1,4,E=95)
# Rabbit(14,3,E=95)
# Rabbit(17,8,E=115)
# Rabbit(12,3,E=95)
# Rabbit(3,18,E=95)
# Fox(13,3,E=95)
# Fox(1,11,E=95)
# Fox(13,17,E=118)
# Fox(8,14,E=95)
# Fox(19,8,E=95)
# Fox(2,13,E=95)
# Fox(4,13,E=95)
# Carrot(11,1,E=100)
# Carrot(10,1,E=100)
#
# --- Step 5 ---
# Carrot(12,2,E=100)
# Carrot(12,1,E=100)
# Carrot(10,0,E=100)
# Rabbit(5,15,E=94)
# Rabbit(19,16,E=94)
# Rabbit(3,0,E=94)
# Rabbit(6,13,E=94)
# Rabbit(15,19,E=94)
# Rabbit(13,16,E=96) X
# Rabbit(9,18,E=94)
# Rabbit(10,13,E=94)
# Rabbit(13,17,E=99) X
# Rabbit(8,1,E=94)
# Rabbit(2,5,E=94)
# Rabbit(12,3,E=94)
# Rabbit(17,9,E=114)
# Rabbit(13,3,E=94) X
# Rabbit(2,18,E=94)
# Fox(12,4,E=114)
# Fox(1,11,E=94)
# Fox(12,18,E=117)
# Fox(9,14,E=94)
# Fox(19,7,E=94)
# Fox(3,14,E=94)
# Fox(3,12,E=94)
# Carrot(11,1,E=100)
# Carrot(10,1,E=100)
#
# --- Step 6 ---
# Carrot(12,2,E=100)
# Carrot(12,1,E=100)
# Carrot(10,0,E=100)
# Rabbit(3,15,E=93)
# Rabbit(19,15,E=93)
# Rabbit(2,0,E=93)
# Rabbit(7,14,E=93)
# Rabbit(15,18,E=93)
# Rabbit(13,16,E=96) X
# Rabbit(10,19,E=93)
# Rabbit(9,13,E=93)
# Rabbit(13,17,E=99) X
# Rabbit(9,1,E=93)
# Rabbit(2,6,E=93)
# Rabbit(11,3,E=93)
# Rabbit(18,9,E=113)
# Rabbit(13,3,E=94) X
# Rabbit(2,19,E=93)
# Fox(11,3,E=113)
# Fox(2,12,E=93)
# Fox(11,17,E=116)
# Fox(8,13,E=93)
# Fox(19,7,E=93)
# Fox(4,15,E=93)
# Fox(3,13,E=93)
# Carrot(11,1,E=100)
# Carrot(10,1,E=100)
# 💀 Decomposed: Rabbit(13,16,E=96)
#
# --- Step 7 ---
# Carrot(12,2,E=100)
# Carrot(12,1,E=100)
# Carrot(10,0,E=100)
# Rabbit(4,14,E=92)
# Rabbit(18,15,E=92)
# Rabbit(3,0,E=92)
# Rabbit(9,12,E=92)
# Rabbit(15,19,E=92)
# Rabbit(10,17,E=92)
# Rabbit(9,12,E=92)
# Rabbit(13,17,E=99) X
# Rabbit(10,2,E=92)
# Rabbit(3,5,E=92)
# Rabbit(11,3,E=92) X
# Rabbit(19,8,E=112)
# Rabbit(13,3,E=94) X
# Rabbit(2,19,E=92)
# Fox(12,4,E=119)
# Fox(3,13,E=92)
# Fox(10,18,E=115)
# Fox(7,14,E=92)
# Fox(19,8,E=92)
# Fox(4,14,E=92)
# Fox(4,14,E=92)
# Carrot(11,1,E=100)
# Carrot(10,1,E=100)
#
# --- Step 8 ---
# Carrot(12,2,E=100)
# Carrot(12,1,E=100)
# Carrot(10,0,E=100)
# Rabbit(5,12,E=91)
# Rabbit(18,14,E=91)
# Rabbit(4,0,E=91)
# Rabbit(8,11,E=91)
# Rabbit(15,18,E=91)
# Rabbit(10,18,E=91) X
# Rabbit(9,13,E=91)
# Rabbit(13,17,E=99) X
# Rabbit(11,1,E=91)
# Rabbit(2,6,E=91)
# Rabbit(11,3,E=92) X
# Rabbit(18,7,E=111)
# Rabbit(13,3,E=94) X
# Rabbit(2,19,E=91)
# Fox(12,3,E=118)
# Fox(2,13,E=91)
# Fox(10,17,E=119)
# Fox(6,13,E=91)
# Fox(19,7,E=91)
# Fox(4,15,E=91)
# Fox(3,14,E=91)
# Carrot(11,1,E=100)
# Carrot(10,1,E=100)
# Fox(4,13,E=99)
#
# --- Step 9 ---
# Carrot(12,2,E=100) X
# Carrot(12,1,E=100)
# Carrot(10,0,E=100)
# Rabbit(4,12,E=90)
# Rabbit(19,13,E=90)
# Rabbit(4,1,E=90)
# Rabbit(8,10,E=90)
# Rabbit(15,17,E=90)
# Rabbit(10,18,E=91) X
# Rabbit(9,14,E=90)
# Rabbit(13,17,E=99) X
# Rabbit(11,1,E=110)
# Rabbit(3,5,E=90)
# Rabbit(11,3,E=92) X
# Rabbit(19,7,E=110) X
# Rabbit(13,3,E=94) X
# Rabbit(3,18,E=90)
# Fox(12,3,E=117)
# Fox(3,12,E=90)
# Fox(10,18,E=118)
# Fox(5,12,E=90)
# Fox(19,6,E=110)
# Fox(3,15,E=90)
# Fox(3,13,E=90)
# Carrot(11,1,E=100)
# Carrot(10,1,E=100)
# Fox(3,14,E=98)
# 💀 Decomposed: Carrot(12,2,E=100)
#
# --- Step 10 ---
# Carrot(12,1,E=100)
# Carrot(10,0,E=100)
# Rabbit(2,12,E=89)
# Rabbit(19,12,E=89)
# Rabbit(3,1,E=89)
# Rabbit(9,10,E=89)
# Rabbit(14,17,E=89)
# Rabbit(10,18,E=91) X
# Rabbit(10,13,E=89)
# Rabbit(13,17,E=99) X
# Rabbit(12,2,E=109)
# Rabbit(4,6,E=89)
# Rabbit(11,3,E=92) X
# Rabbit(19,7,E=110) X
# Rabbit(13,3,E=94) X
# Rabbit(3,17,E=89)
# Fox(13,3,E=116)
# Fox(2,11,E=89)
# Fox(11,17,E=117)
# Fox(6,12,E=89)
# Fox(19,7,E=109)
# Fox(3,16,E=89)
# Fox(3,12,E=89)
# Carrot(11,1,E=100)
# Carrot(10,1,E=100)
# Fox(4,13,E=97)
#
# --- Step 11 ---
# Carrot(12,1,E=100)
# Carrot(10,0,E=100)
# Rabbit(2,12,E=88)
# Rabbit(19,12,E=88)
# Rabbit(2,1,E=88)
# Rabbit(8,11,E=88)
# Rabbit(13,17,E=88)
# Rabbit(10,18,E=91) X
# Rabbit(10,14,E=88)
# Rabbit(13,17,E=99) X
# Rabbit(13,3,E=108) X
# Rabbit(4,7,E=88)
# Rabbit(11,3,E=92) X
# Rabbit(19,7,E=110) X
# Rabbit(13,3,E=94) X
# Rabbit(2,16,E=88)
# Fox(14,2,E=119)
# Fox(1,11,E=88)
# Fox(11,18,E=116)
# Fox(7,11,E=88)
# Fox(18,6,E=108)
# Fox(2,16,E=88)
# Fox(2,13,E=88)
# Carrot(11,1,E=100)
# Carrot(10,1,E=100)
# Fox(5,12,E=96)
#
# --- Step 12 ---
# Carrot(12,1,E=100)
# Carrot(10,0,E=100)
# Rabbit(2,11,E=87)
# Rabbit(18,13,E=87)
# Rabbit(3,2,E=87)
# Rabbit(7,10,E=87)
# Rabbit(12,19,E=87)
# Rabbit(10,18,E=91) X
# Rabbit(10,13,E=87)
# Rabbit(13,17,E=99) X
# Rabbit(13,3,E=108) X
# Rabbit(4,8,E=87)
# Rabbit(11,3,E=92) X
# Rabbit(19,7,E=110) X
# Rabbit(13,3,E=94) X
# Rabbit(1,14,E=87)
# Fox(14,1,E=118)
# Fox(2,12,E=87)
# Fox(11,18,E=115)
# Fox(8,10,E=87)
# Fox(18,7,E=107)
# Fox(2,17,E=87)
# Fox(3,13,E=87)
# Carrot(11,1,E=100)
# Carrot(10,1,E=100)
# Fox(6,13,E=95)
# 💀 Decomposed: Rabbit(10,18,E=91)
#
# --- Step 13 ---
# Carrot(12,1,E=100)
# Carrot(10,0,E=100)
# Rabbit(3,13,E=86) X
# Rabbit(19,14,E=86)
# Rabbit(3,1,E=86)
# Rabbit(8,11,E=86)
# Rabbit(12,18,E=86)
# Rabbit(11,13,E=86)
# Rabbit(13,17,E=99) X
# Rabbit(13,3,E=108) X
# Rabbit(4,8,E=86)
# Rabbit(11,3,E=92) X
# Rabbit(19,7,E=110) X
# Rabbit(13,3,E=94) X
# Rabbit(1,14,E=86)
# Fox(13,0,E=117)
# Fox(2,11,E=86)
# Fox(11,19,E=114)
# Fox(8,10,E=86)
# Fox(19,7,E=106)
# Fox(1,16,E=86)
# Fox(3,12,E=106)
# Carrot(11,1,E=100)
# Carrot(10,1,E=100)
# Fox(6,13,E=94)
#
# --- Step 14 ---
# Carrot(12,1,E=100)
# Carrot(10,0,E=100)
# Rabbit(3,13,E=86) X
# Rabbit(19,14,E=85)
# Rabbit(3,2,E=85)
# Rabbit(9,9,E=85)
# Rabbit(11,18,E=85)
# Rabbit(12,12,E=85)
# Rabbit(13,17,E=99) X
# Rabbit(13,3,E=108) X
# Rabbit(4,9,E=85)
# Rabbit(11,3,E=92) X
# Rabbit(19,7,E=110) X
# Rabbit(13,3,E=94) X
# Rabbit(1,16,E=85) X
# Fox(13,0,E=116)
# Fox(3,12,E=85)
# Fox(11,19,E=113)
# Fox(7,9,E=85)
# Fox(18,7,E=105)
# Fox(2,17,E=105)
# Fox(4,13,E=105)
# Carrot(11,1,E=100)
# Carrot(10,1,E=100)
# Fox(5,12,E=93)
#
# --- Step 15 ---
# Carrot(12,1,E=100)
# Carrot(10,0,E=100)
# Rabbit(3,13,E=86) X
# Rabbit(18,13,E=84)
# Rabbit(4,2,E=84)
# Rabbit(8,9,E=84)
# Rabbit(10,19,E=84)
# Rabbit(12,11,E=84)
# Rabbit(13,17,E=99) X
# Rabbit(13,3,E=108) X
# Rabbit(6,9,E=84)
# Rabbit(11,3,E=92) X
# Rabbit(19,7,E=110) X
# Rabbit(13,3,E=94) X
# Rabbit(1,16,E=85) X
# Fox(13,1,E=115)
# Fox(2,11,E=84)
# Fox(12,19,E=112)
# Fox(8,9,E=84)
# Fox(19,7,E=104)
# Fox(1,17,E=104)
# Fox(5,12,E=104)
# Carrot(11,1,E=100)
# Carrot(10,1,E=100)
# Fox(5,12,E=92)
# 💀 Decomposed: Rabbit(3,13,E=86)
#
# --- Step 16 ---
# Carrot(12,1,E=100)
# Carrot(10,0,E=100)
# Rabbit(19,14,E=83)
# Rabbit(5,1,E=83)
# Rabbit(8,8,E=83)
# Rabbit(11,19,E=83)
# Rabbit(13,12,E=83)
# Rabbit(13,17,E=99) X
# Rabbit(13,3,E=108) X
# Rabbit(6,10,E=83)
# Rabbit(11,3,E=92) X
# Rabbit(19,7,E=110) X
# Rabbit(13,3,E=94) X
# Rabbit(1,16,E=85) X
# Fox(12,2,E=114)
# Fox(3,12,E=83)
# Fox(13,19,E=111)
# Fox(9,8,E=83)
# Fox(19,6,E=103)
# Fox(2,18,E=103)
# Fox(5,13,E=103)
# Carrot(11,1,E=100)
# Carrot(10,1,E=100)
# Fox(5,11,E=91)
#
# --- Step 17 ---
# Carrot(12,1,E=100)
# Carrot(10,0,E=100)
# Rabbit(18,13,E=82)
# Rabbit(5,1,E=82)
# Rabbit(8,9,E=82)
# Rabbit(13,18,E=82)
# Rabbit(13,11,E=82)
# Rabbit(13,17,E=99) X
# Rabbit(13,3,E=108) X
# Rabbit(5,11,E=82) X
# Rabbit(11,3,E=92) X
# Rabbit(19,7,E=110) X
# Rabbit(13,3,E=94) X
# Rabbit(1,16,E=85) X
# Fox(11,3,E=113)
# Fox(4,12,E=82)
# Fox(14,18,E=110)
# Fox(8,8,E=82)
# Fox(19,6,E=102)
# Fox(1,18,E=102)
# Fox(4,12,E=102)
# Carrot(11,1,E=100)
# Carrot(10,1,E=100)
# Fox(6,10,E=110)
#
# --- Step 18 ---
# Carrot(12,1,E=100)
# Carrot(10,0,E=100)
# Rabbit(18,12,E=81)
# Rabbit(6,2,E=81)
# Rabbit(8,8,E=81) X
# Rabbit(14,19,E=81)
# Rabbit(13,10,E=81)
# Rabbit(13,17,E=99) X
# Rabbit(13,3,E=108) X
# Rabbit(5,11,E=82) X
# Rabbit(11,3,E=92) X
# Rabbit(19,7,E=110) X
# Rabbit(13,3,E=94) X
# Rabbit(1,16,E=85) X
# Fox(12,4,E=112)
# Fox(4,13,E=81)
# Fox(14,19,E=109)
# Fox(7,7,E=101)
# Fox(19,7,E=101)
# Fox(2,17,E=101)
# Fox(4,12,E=101)
# Carrot(11,1,E=100)
# Carrot(10,1,E=100)
# Fox(6,9,E=109)
# 💀 Decomposed: Rabbit(8,8,E=81)
#
# --- Step 19 ---
# Carrot(12,1,E=100)
# Carrot(10,0,E=100)
# Rabbit(17,12,E=80)
# Rabbit(5,1,E=80)
# Rabbit(14,18,E=80)
# Rabbit(13,10,E=80)
# Rabbit(13,17,E=99) X
# Rabbit(13,3,E=108) X
# Rabbit(5,11,E=82) X
# Rabbit(11,3,E=92) X
# Rabbit(19,7,E=110) X
# Rabbit(13,3,E=94) X
# Rabbit(1,16,E=85) X
# Fox(12,5,E=111)
# Fox(3,12,E=80)
# Fox(14,19,E=108)
# Fox(8,8,E=100)
# Fox(18,6,E=100)
# Fox(3,18,E=100)
# Fox(3,12,E=100)
# Carrot(11,1,E=100)
# Carrot(10,1,E=100)
# Fox(5,8,E=108)

# %%
import importlib
import visualizer.plot
importlib.reload(visualizer.plot)
from visualizer.plot import create_animation

os.chdir("c:/Users/Surface/Documents/2024_25_4/ScientificPython/ecosim") # path/to/ecosim
create_animation(frame_folder="frames", output_path="statistics_plots/animation.gif", frame_range=(0, 21))
# Out:
# ✅ Animation saved to statistics_plots/animation.gif

# %%
from visualizer.plot import compose_frames_side_by_side
compose_frames_side_by_side([6, 7, 10])
# Out:
# ✅ Composed image saved to statistics_plots/frames_side_by_side.png

# %% [markdown]
# STATISTICS - HEATMAP

# %%
import importlib
import statistic_tools.heatmap
importlib.reload(statistic_tools.heatmap)

from statistic_tools.heatmap import display_heatmap
display_heatmap("Fox")

# %% [markdown]
# STATISTICS - POPULATION CHART

# %%
import importlib
import statistic_tools.population
importlib.reload(statistic_tools.population)

from statistic_tools.population import display_population_chart
display_population_chart()
